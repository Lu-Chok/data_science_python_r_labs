# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.5.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (5.11.0)
# Requirement already satisfied: rpy2==3.5.1 in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.5.1)
# Requirement already satisfied: pyreadr in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.4.7)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (5.7.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/site-packages (from rpy2==3.5.1->-r requirements.txt (line 3)) (2022.6)
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.10/site-packages (from rpy2==3.5.1->-r requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/site-packages (from rpy2==3.5.1->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/site-packages (from rpy2==3.5.1->-r requirements.txt (line 3)) (4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/site-packages (from plotly->-r requirements.txt (line 2)) (8.1.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/site-packages (from nbformat>=4.2.0->-r requirements.txt (line 5)) (2.16.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.2.0->-r requirements.txt (line 5)) (5.7.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/site-packages (from nbformat>=4.2.0->-r requirements.txt (line 5)) (4.17.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/site-packages (from nbformat>=4.2.0->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi>=1.10.0->rpy2==3.5.1->-r requirements.txt (line 3)) (2.21)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r requirements.txt (line 5)) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->-r requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2->rpy2==3.5.1->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/site-packages (from jupyter-core->nbformat>=4.2.0->-r requirements.txt (line 5)) (2.6.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/site-packages (from tzlocal->rpy2==3.5.1->-r requirements.txt (line 3)) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal->rpy2==3.5.1->-r requirements.txt (line 3)) (2022.7)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# %load_ext rpy2.ipython
# Out:
# Во время загрузки - Предупреждения:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%R
# install.packages("stringr")
# Out:
# --- Пожалуйста, выберите зеркало CRAN для использования в этой сессии ---
# Secure CRAN mirrors
#
#  1: 0-Cloud [https]
#  2: Australia (Canberra) [https]
#  3: Australia (Melbourne 1) [https]
#  4: Australia (Melbourne 2) [https]
#  5: Australia (Perth) [https]
#  6: Austria [https]
#  7: Belgium (Brussels) [https]
#  8: Brazil (PR) [https]
#  9: Brazil (RJ) [https]
# 10: Brazil (SP 1) [https]
# 11: Brazil (SP 2) [https]
# 12: Bulgaria [https]
# 13: Canada (MB) [https]
# 14: Canada (ON 3) [https]
# 15: Chile (Santiago) [https]
# 16: China (Beijing 2) [https]
# 17: China (Beijing 3) [https]
# 18: China (Hefei) [https]
# 19: China (Hong Kong) [https]
# 20: China (Guangzhou) [https]
# 21: China (Jinan) [https]
# 22: China (Lanzhou) [https]
# 23: China (Nanjing) [https]
# 24: China (Shanghai 2) [https]
# 25: China (Shenzhen) [https]
# 26: Colombia (Cali) [https]
# 27: Costa Rica [https]
# 28: Cyprus [https]
# 29: Czech Republic [https]
# 30: Denmark [https]
# 31: East Asia [https]
# 32: Ecuador (Cuenca) [https]
# 33: Ecuador (Quito) [https]
# 34: France (Lyon 1) [https]
# 35: France (Lyon 2) [https]
# 36: France (Marseille) [https]
# 37: France (Paris 1) [https]
# 38: Germany (Erlangen) [https]
# 39: Germany (Leipzig) [https]
# 40: Germany (Göttingen) [https]
# 41: Germany (Münster) [https]
# 42: Germany (Regensburg) [https]
# 43: Greece [https]
# 44: Hungary [https]
# 45: Iceland [https]
# 46: India [https]
# 47: Indonesia (Banda Aceh) [https]
# 48: Iran (Mashhad) [https]
# 49: Italy (Milano) [https]
# 50: Italy (Padua) [https]
# 51: Japan (Tokyo) [https]
# 52: Japan (Yonezawa) [https]
# 53: Korea (Gyeongsan-si) [https]
# 54: Korea (Ulsan) [https]
# 55: Malaysia [https]
# 56: Mexico (Mexico City) [https]
# 57: Mexico (Texcoco) [https]
# 58: Morocco [https]
# 59: Netherlands (Dronten) [https]
# 60: New Zealand [https]
# 61: Norway [https]
# 62: South Africa (Johannesburg) [https]
# 63: Spain (A Coruña) [https]
# 64: Spain (Madrid) [https]
# 65: Sweden (Borås) [https]
# 66: Sweden (Umeå) [https]
# 67: Switzerland (Zurich 1) [https]
# 68: Taiwan (Taipei) [https]
# 69: Turkey (Denizli) [https]
# 70: Turkey (Istanbul) [https]
# 71: Turkey (Mersin) [https]
# 72: UK (Bristol) [https]
# 73: UK (London 1) [https]
# 74: USA (IA) [https]
# 75: USA (MI) [https]
# 76: USA (MO) [https]
# 77: USA (OH) [https]
# 78: USA (OR) [https]
# 79: USA (TN) [https]
# 80: USA (TX 1) [https]
# 81: United Arab Emirates [https]
# 82: Uruguay [https]
# 83: (other mirrors)
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/stringr_1.5.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 175699 bytes (171 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 171 KB
#
#
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘stringr’ ...
# ** пакет ‘stringr’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (stringr)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: Скачанные исходники пакетов находятся в
# 	‘/private/var/folders/_l/lvwb30511nx39kk2yr5zsbxm0000gn/T/Rtmpl7LPot/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Обновляю HTML-список пакетов в '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  готово
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"

# %% [markdown]
# # Part 1

# %%
# %%R
# df <- readRDS('data/hike_data.rds')

# %%
# %%R
# head(df, 6)
# Out:
#                   name                                       location
# 1 Lake Hills Greenbelt Puget Sound and Islands -- Seattle-Tacoma Area
# 2            Snow Lake           Snoqualmie Region -- Snoqualmie Pass
# 3        Skookum Flats   Mount Rainier Area -- Chinook Pass - Hwy 410
# 4      Teneriffe Falls           Snoqualmie Region -- North Bend Area
# 5           Twin Falls           Snoqualmie Region -- North Bend Area
# 6        Chenuis Falls Mount Rainier Area -- NW - Carbon River/Mowich
#                 length gain highpoint rating
# 1 2.3 miles, roundtrip   50     330.0   3.67
# 2 7.2 miles, roundtrip 1800    4400.0   4.16
# 3 7.8 miles, roundtrip  300    2550.0   3.68
# 4 5.6 miles, roundtrip 1585    2370.0   3.92
# 5 2.6 miles, roundtrip  500    1000.0   4.14
# 6 8.0 miles, roundtrip  500    2200.0   3.14
#                                                                                                                    features
# 1                                                       Dogs allowed on leash, Wildlife, Good for kids, Lakes, Fall foliage
# 2 Ridges/passes, Dogs allowed on leash, Established campsites, Mountain views, Old growth, Waterfalls, Good for kids, Lakes
# 3       Wildflowers/Meadows, Mountain views, Wildlife, Waterfalls, Old growth, Good for kids, Dogs allowed on leash, Rivers
# 4                                                    Wildflowers/Meadows, Mountain views, Dogs allowed on leash, Waterfalls
# 5                                                      Old growth, Rivers, Good for kids, Dogs allowed on leash, Waterfalls
# 6                                           Mountain views, Waterfalls, Old growth, Good for kids, Dogs not allowed, Rivers
#                                                                                                                                                                                                                                                                                                                  description
# 1        Hike through a pastoral area first settled and farmed in the 1880s. Along the way, enjoy a dense grove of cedars, followed by close-up views of blueberry fields that still produce an annual crop. Circle Larsen Lake, and view a restored pioneer home. Optionally, extend your hike to view nearby Phantom Lake.
# 2 A relatively short and easy hike within a stone’s throw of Seattle, Snow Lake delivers splendorous alpine scenery – crystal clear waters, towering peaks – at a mere pittance of sweat and toil. Just don’t expect to have the trail to yourself – Snow Lake is Washington's most heavily-used trail in a wilderness area!
# 3                                                                                                                                                                                                                 Choose between a shorter or longer river walk through old-growth forest to a 250-foot cascading waterfall.
# 4                                     You'll work up a sweat on this easy to moderate hike to the spectacular Teneriffe Falls. Go in the spring when the tread is snow-free and the waterfall is flowing at full volume. Along the way, you'll be rewarded with views of the surrounding Snoqualmie valley and nearby peaks.
# 5                                                                                                                                                                                                             Visit a trio (yes, trio) of waterfalls just off I-90 on this sure-to-please short trail, perfect for families.
# 6                                                                                                                                                                                                              A long walk (or short mountain bike ride!) leads to a rolling falls that feeds into the rushing Carbon River.

# %% [markdown]
# Create a new dataset clean_hike_trails with the next updates:
# 1. Convert columns gain, highpoint, rating to numeric values.
# 2. Add new column trip with the type of trip from column length (“roundtrip”, “trails”,
# “one-way”).
# 3. Add new column length_total with the route length from column length, considering
# that for “one-way” trip you must double the route length.
# 4. Add new column location_general with location from column location (a part before
# “–”).
# 5. Add column id with row number

# %% [markdown]
# **Changing value types to numeric**

# %%
# %%R
# library(stringr)
# clean_hike_trails <- df
# clean_hike_trails[, 4:6] <- sapply(clean_hike_trails[, 4:6], as.numeric)

# %% [markdown]
# **Getting trip type from length**

# %%
# %%R
# clean_hike_trails$trip <- sub('..', '', str_extract(df$length,",.*"))

# %% [markdown]
# **Doubling lenght if one way trip**

# %%
# %%R
# clean_hike_trails$length_numeric<-sapply(gsub("[^0-9]","",clean_hike_trails$length), as.numeric)
# clean_hike_trails$length_total <- with(clean_hike_trails, ifelse(trip == "one-way", clean_hike_trails$length_numeric*2, clean_hike_trails$length_numeric))

# %% [markdown]
# **Adding id column**

# %%
# %%R
# clean_hike_trails$location_general <- sub(' --', '',  str_extract(df$location,".*--"))
# clean_hike_trails$ID <- seq.int(nrow(clean_hike_trails))

# %%
# %%R
# head(clean_hike_trails$features, 6)
# Out:
# [[1]]
# [1] "Dogs allowed on leash" "Wildlife"              "Good for kids"
# [4] "Lakes"                 "Fall foliage"
#
# [[2]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Established campsites"
# [4] "Mountain views"        "Old growth"            "Waterfalls"
# [7] "Good for kids"         "Lakes"
#
# [[3]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Waterfalls"            "Old growth"            "Good for kids"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[4]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"
#
# [[5]]
# [1] "Old growth"            "Rivers"                "Good for kids"
# [4] "Dogs allowed on leash" "Waterfalls"
#
# [[6]]
# [1] "Mountain views"   "Waterfalls"       "Old growth"       "Good for kids"
# [5] "Dogs not allowed" "Rivers"

# %% [markdown]
# Question 1. How many routes have rating more than 4.9

# %%
# %%R
# install.packages("dplyr")
# library(dplyr)
# Out:
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/dplyr_1.0.10.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 884984 bytes (864 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 864 KB
#
#
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘dplyr’ ...
# ** пакет ‘dplyr’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c chop.cpp -o chop.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c filter.cpp -o filter.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c funs.cpp -o funs.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c group_by.cpp -o group_by.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c group_data.cpp -o group_data.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c imports.cpp -o imports.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c init.cpp -o init.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c mask.cpp -o mask.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c mutate.cpp -o mutate.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c slice.cpp -o slice.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c summarise.cpp -o summarise.o
# clang++ -std=gnu++14 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o dplyr.so chop.o filter.o funs.o group_by.o group_data.o imports.o init.o mask.o mutate.o slice.o summarise.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-dplyr/00new/dplyr/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (dplyr)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: Скачанные исходники пакетов находятся в
# 	‘/private/var/folders/_l/lvwb30511nx39kk2yr5zsbxm0000gn/T/Rtmpl7LPot/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Обновляю HTML-список пакетов в '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  готово
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"

# %%
# %%R
# n_distinct(clean_hike_trails[clean_hike_trails$rating > 4.9, ])
# Out:
# [1] 68

# %% [markdown]
# Question 2. How many routes are “Good for kids” (hint: you can use (unnest function)?

# %%
# %%R
# n_distinct(clean_hike_trails[clean_hike_trails$features == "Good for kids", ])
# Out:
# [1] 3

# %% [markdown]
# Question 3. Which unique features can routes have?

# %%
# %%R
# install.packages("tidyr")
# library(tidyr)
# Out:
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/tidyr_1.2.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 746056 bytes (728 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 728 KB
#
#
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘tidyr’ ...
# ** пакет ‘tidyr’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c cpp11.cpp -o cpp11.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c melt.cpp -o melt.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c simplifyPieces.cpp -o simplifyPieces.o
# clang++ -std=gnu++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o tidyr.so cpp11.o melt.o simplifyPieces.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-tidyr/00new/tidyr/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (tidyr)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: Скачанные исходники пакетов находятся в
# 	‘/private/var/folders/_l/lvwb30511nx39kk2yr5zsbxm0000gn/T/Rtmpl7LPot/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Обновляю HTML-список пакетов в '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  готово
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"

# %%
# %%R
# clean_hike_trails %>% nest(data = c("features"))
# unique(clean_hike_trails$features)
# Out:
# [[1]]
# [1] "Dogs allowed on leash" "Wildlife"              "Good for kids"
# [4] "Lakes"                 "Fall foliage"
#
# [[2]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Established campsites"
# [4] "Mountain views"        "Old growth"            "Waterfalls"
# [7] "Good for kids"         "Lakes"
#
# [[3]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Waterfalls"            "Old growth"            "Good for kids"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[4]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"
#
# [[5]]
# [1] "Old growth"            "Rivers"                "Good for kids"
# [4] "Dogs allowed on leash" "Waterfalls"
#
# [[6]]
# [1] "Mountain views"   "Waterfalls"       "Old growth"       "Good for kids"
# [5] "Dogs not allowed" "Rivers"
#
# [[7]]
# [1] "Dogs not allowed" "Good for kids"    "Fall foliage"
#
# [[8]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Good for kids"
# [4] "Dogs allowed on leash" "Fall foliage"          "Rivers"
#
# [[9]]
# [1] "Wildlife"              "Good for kids"         "Dogs allowed on leash"
# [4] "Rivers"
#
# [[10]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Rivers"
#
# [[11]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Good for kids"
# [4] "Dogs allowed on leash" "Fall foliage"
#
# [[12]]
# [1] "Dogs allowed on leash" "Waterfalls"            "Good for kids"
# [4] "Lakes"                 "Fall foliage"          "Rivers"
#
# [[13]]
# [1] "Mountain views"        "Dogs allowed on leash" "Coast"
# [4] "Rivers"
#
# [[14]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Established campsites" "Mountain views"        "Old growth"
# [7] "Waterfalls"
#
# [[15]]
# [1] "Dogs allowed on leash" "Established campsites" "Waterfalls"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Fall foliage"          "Rivers"
#
# [[16]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Ridges/passes"
#
# [[17]]
# [1] "Mountain views" "Good for kids"
#
# [[18]]
# [1] "Dogs allowed on leash" "Lakes"                 "Established campsites"
#
# [[19]]
# [1] "Mountain views"        "Dogs allowed on leash" "Lakes"
# [4] "Ridges/passes"
#
# [[20]]
# [1] "Mountain views" "Summits"        "Good for kids"
#
# [[21]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
#
# [[22]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Summits"               "Good for kids"         "Dogs allowed on leash"
# [7] "Fall foliage"          "Coast"
#
# [[23]]
# [1] "Mountain views"        "Dogs allowed on leash" "Established campsites"
# [4] "Waterfalls"            "Old growth"            "Lakes"
# [7] "Rivers"
#
# [[24]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Fall foliage"          "Rivers"
#
# [[25]]
# [1] "Dogs allowed on leash" "Good for kids"         "Lakes"
#
# [[26]]
# [1] "Lakes"  "Rivers"
#
# [[27]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Dogs not allowed"    "Summits"             "Good for kids"
# [7] "Lakes"
#
# [[28]]
# [1] "Mountain views"        "Old growth"            "Dogs allowed on leash"
# [4] "Rivers"
#
# [[29]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
#
# [[30]]
# [1] "Old growth" "Rivers"     "Wildlife"   "Waterfalls"
#
# [[31]]
# [1] "Dogs allowed on leash" "Rivers"                "Good for kids"
# [4] "Waterfalls"
#
# [[32]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Ridges/passes"         "Dogs allowed on leash" "Fall foliage"
#
# [[33]]
# [1] "Dogs allowed on leash" "Old growth"            "Good for kids"
# [4] "Wildlife"              "Fall foliage"
#
# [[34]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Old growth"            "Summits"               "Good for kids"
# [7] "Dogs allowed on leash" "Fall foliage"          "Coast"
#
# [[35]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"         "Old growth"            "Summits"
#
# [[36]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Mountain views"        "Old growth"            "Summits"
# [7] "Lakes"
#
# [[37]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Dogs not allowed"
# [4] "Ridges/passes"       "Old growth"          "Lakes"
#
# [[38]]
# [1] "Mountain views"        "Wildlife"              "Dogs allowed on leash"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Fall foliage"
#
# [[39]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Lakes"                 "Ridges/passes"
#
# [[40]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Good for kids"       "Fall foliage"
#
# [[41]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Summits"               "Good for kids"
# [7] "Lakes"                 "Fall foliage"          "Coast"
#
# [[42]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Good for kids"         "Dogs allowed on leash" "Fall foliage"
# [7] "Coast"
#
# [[43]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Established campsites" "Ridges/passes"
#
# [[44]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Old growth"
# [4] "Good for kids"         "Dogs allowed on leash" "Fall foliage"
#
# [[45]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Established campsites"
# [4] "Good for kids"         "Lakes"                 "Fall foliage"
#
# [[46]]
# [1] "Old growth"       "Rivers"           "Good for kids"    "Dogs not allowed"
# [5] "Waterfalls"
#
# [[47]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Good for kids"
# [4] "Dogs allowed on leash" "Rivers"
#
# [[48]]
# [1] "Mountain views"        "Dogs allowed on leash" "Rivers"
# [4] "Lakes"                 "Ridges/passes"
#
# [[49]]
# [1] "Mountain views" "Summits"        "Good for kids"  "Lakes"
#
# [[50]]
# [1] "Old growth"    "Good for kids" "Wildlife"
#
# [[51]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Good for kids"         "Ridges/passes"
#
# [[52]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Old growth"            "Good for kids"
# [7] "Lakes"                 "Fall foliage"
#
# [[53]]
# [1] "Mountain views"        "Wildlife"              "Old growth"
# [4] "Summits"               "Good for kids"         "Dogs allowed on leash"
# [7] "Fall foliage"
#
# [[54]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Ridges/passes"
#
# [[55]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"            "Good for kids"         "Ridges/passes"
# [7] "Fall foliage"
#
# [[56]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"
#
# [[57]]
# [1] "Dogs allowed on leash" "Established campsites" "Waterfalls"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Rivers"
#
# [[58]]
# [1] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [4] "Fall foliage"          "Rivers"
#
# [[59]]
# [1] "Summits"       "Good for kids" "Rivers"        "Fall foliage"
# [5] "Waterfalls"
#
# [[60]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Waterfalls"            "Dogs allowed on leash" "Old growth"
# [7] "Good for kids"         "Lakes"                 "Rivers"
#
# [[61]]
# [1] "Mountain views"        "Dogs allowed on leash" "Old growth"
# [4] "Summits"               "Good for kids"         "Fall foliage"
#
# [[62]]
# [1] "Mountain views" "Wildlife"       "Summits"        "Fall foliage"
#
# [[63]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Established campsites"
# [4] "Dogs allowed on leash" "Good for kids"         "Lakes"
# [7] "Fall foliage"
#
# [[64]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Established campsites"
# [4] "Mountain views"        "Old growth"            "Summits"
# [7] "Rivers"
#
# [[65]]
# [1] "Mountain views" "Lakes"          "Rivers"
#
# [[66]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Old growth"            "Summits"
# [7] "Fall foliage"
#
# [[67]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Fall foliage"
# [4] "Rivers"
#
# [[68]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Dogs not allowed"
# [4] "Old growth"          "Good for kids"       "Lakes"
# [7] "Fall foliage"
#
# [[69]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Good for kids"         "Lakes"                 "Fall foliage"
#
# [[70]]
#  [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
#  [4] "Summits"               "Lakes"                 "Wildflowers/Meadows"
#  [7] "Mountain views"        "Established campsites" "Waterfalls"
# [10] "Fall foliage"
#
# [[71]]
# [1] "Wildlife"              "Good for kids"         "Dogs allowed on leash"
# [4] "Fall foliage"
#
# [[72]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Wildlife"
# [4] "Lakes"
#
# [[73]]
# [1] "Dogs allowed on leash" "Good for kids"         "Lakes"
# [4] "Established campsites"
#
# [[74]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Established campsites"
#
# [[75]]
# [1] "Old growth"    "Good for kids" "Rivers"
#
# [[76]]
# [1] "Mountain views"        "Wildlife"              "Established campsites"
# [4] "Old growth"            "Good for kids"         "Dogs not allowed"
# [7] "Rivers"
#
# [[77]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs allowed on leash" "Old growth"
# [7] "Good for kids"         "Lakes"                 "Rivers"
#
# [[78]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Good for kids"         "Fall foliage"
#
# [[79]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Old growth"            "Summits"               "Good for kids"
#
# [[80]]
# [1] "Dogs allowed on leash" "Rivers"
#
# [[81]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
#
# [[82]]
# [1] "Mountain views"        "Dogs allowed on leash" "Established campsites"
# [4] "Ridges/passes"         "Fall foliage"          "Rivers"
#
# [[83]]
# [1] "Mountain views"        "Dogs allowed on leash" "Rivers"
# [4] "Fall foliage"          "Ridges/passes"
#
# [[84]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Summits"
# [7] "Good for kids"         "Dogs allowed on leash" "Fall foliage"
#
# [[85]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Old growth"            "Rivers"
#
# [[86]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Fall foliage"
# [4] "Mountain views"      "Summits"             "Lakes"
# [7] "Waterfalls"
#
# [[87]]
# [1] "Mountain views"        "Dogs not allowed"      "Established campsites"
#
# [[88]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Lakes"
# [4] "Ridges/passes"
#
# [[89]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Ridges/passes"         "Summits"               "Dogs allowed on leash"
#
# [[90]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Good for kids"       "Waterfalls"
#
# [[91]]
# [1] "Mountain views" "Summits"
#
# [[92]]
# [1] "Wildlife"              "Good for kids"         "Dogs allowed on leash"
# [4] "Fall foliage"          "Coast"
#
# [[93]]
# [1] "Dogs allowed on leash" "Wildlife"              "Good for kids"
# [4] "Lakes"
#
# [[94]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Lakes"                 "Fall foliage"
#
# [[95]]
# [1] "Mountain views"        "Wildlife"              "Dogs allowed on leash"
# [4] "Summits"               "Good for kids"         "Lakes"
#
# [[96]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Rivers"
# [4] "Lakes"               "Ridges/passes"
#
# [[97]]
# [1] "Mountain views" "Wildlife"       "Lakes"          "Rivers"
#
# [[98]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Dogs allowed on leash"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Fall foliage"
#
# [[99]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Mountain views"        "Summits"               "Lakes"
# [7] "Rivers"
#
# [[100]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Dogs not allowed"
# [4] "Summits"             "Good for kids"
#
# [[101]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Rivers"
#
# [[102]]
# [1] "Dogs allowed on leash" "Rivers"                "Lakes"
# [4] "Established campsites" "Waterfalls"
#
# [[103]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Dogs not allowed"
# [4] "Good for kids"       "Lakes"               "Fall foliage"
#
# [[104]]
# [1] "Mountain views"   "Dogs not allowed" "Good for kids"
#
# [[105]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Dogs not allowed"    "Waterfalls"          "Rivers"
#
# [[106]]
# [1] "Mountain views"        "Old growth"            "Dogs allowed on leash"
# [4] "Established campsites" "Rivers"
#
# [[107]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Dogs not allowed"
# [4] "Rivers"              "Ridges/passes"
#
# [[108]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"            "Old growth"            "Rivers"
#
# [[109]]
# [1] "Dogs allowed on leash" "Good for kids"
#
# [[110]]
# [1] "Mountain views"
#
# [[111]]
# [1] "Dogs allowed on leash"
#
# [[112]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Fall foliage"          "Mountain views"        "Summits"
# [7] "Waterfalls"
#
# [[113]]
# [1] "Mountain views"        "Dogs allowed on leash"
#
# [[114]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Summits"             "Ridges/passes"
#
# [[115]]
# character(0)
#
# [[116]]
#  [1] "Ridges/passes"         "Wildlife"              "Summits"
#  [4] "Lakes"                 "Wildflowers/Meadows"   "Mountain views"
#  [7] "Dogs allowed on leash" "Established campsites" "Old growth"
# [10] "Fall foliage"
#
# [[117]]
# [1] "Dogs allowed on leash" "Old growth"            "Good for kids"
# [4] "Lakes"                 "Established campsites"
#
# [[118]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Lakes"
#
# [[119]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Fall foliage"          "Rivers"
#
# [[120]]
# [1] "Dogs not allowed" "Wildlife"         "Lakes"
#
# [[121]]
# [1] "Mountain views"        "Dogs allowed on leash" "Established campsites"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Fall foliage"          "Coast"
#
# [[122]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"         "Summits"               "Fall foliage"
#
# [[123]]
# [1] "Wildflowers/Meadows" "Old growth"          "Rivers"
#
# [[124]]
# [1] "Wildlife"              "Dogs allowed on leash" "Rivers"
#
# [[125]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Summits"               "Dogs allowed on leash" "Fall foliage"
#
# [[126]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Fall foliage"
#
# [[127]]
# [1] "Mountain views"        "Dogs allowed on leash" "Waterfalls"
# [4] "Old growth"            "Good for kids"         "Lakes"
# [7] "Rivers"
#
# [[128]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"         "Old growth"            "Fall foliage"
#
# [[129]]
# [1] "Mountain views"        "Old growth"            "Summits"
# [4] "Wildlife"              "Dogs allowed on leash"
#
# [[130]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Fall foliage"
#
# [[131]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Dogs not allowed"    "Ridges/passes"
#
# [[132]]
# [1] "Mountain views"   "Dogs not allowed"
#
# [[133]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs not allowed"
# [4] "Lakes"                 "Established campsites"
#
# [[134]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Dogs not allowed"
# [7] "Waterfalls"
#
# [[135]]
#  [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
#  [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
#  [7] "Established campsites" "Waterfalls"            "Old growth"
# [10] "Fall foliage"
#
# [[136]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Dogs not allowed"    "Good for kids"       "Lakes"
# [7] "Fall foliage"
#
# [[137]]
# [1] "Mountain views"        "Summits"               "Lakes"
# [4] "Established campsites"
#
# [[138]]
# [1] "Dogs not allowed"      "Rivers"                "Established campsites"
# [4] "Waterfalls"
#
# [[139]]
# [1] "Mountain views"   "Dogs not allowed" "Ridges/passes"
#
# [[140]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Dogs not allowed"
# [4] "Good for kids"
#
# [[141]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Dogs not allowed"    "Good for kids"       "Lakes"
#
# [[142]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Dogs not allowed"
# [7] "Lakes"
#
# [[143]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Dogs not allowed"
# [7] "Waterfalls"            "Lakes"
#
# [[144]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Good for kids"         "Lakes"
#
# [[145]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Good for kids"
#
# [[146]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs allowed on leash" "Good for kids"
# [7] "Lakes"                 "Fall foliage"
#
# [[147]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"         "Good for kids"         "Fall foliage"
#
# [[148]]
# [1] "Mountain views"        "Dogs allowed on leash" "Lakes"
# [4] "Fall foliage"
#
# [[149]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [4] "Waterfalls"            "Old growth"            "Good for kids"
# [7] "Dogs not allowed"      "Rivers"
#
# [[150]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Good for kids"
# [4] "Waterfalls"
#
# [[151]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Waterfalls"
# [4] "Good for kids"         "Fall foliage"          "Rivers"
#
# [[152]]
# [1] "Mountain views" "Wildlife"       "Summits"
#
# [[153]]
# [1] "Ridges/passes"         "Wildlife"              "Summits"
# [4] "Lakes"                 "Wildflowers/Meadows"   "Mountain views"
# [7] "Established campsites" "Waterfalls"            "Fall foliage"
#
# [[154]]
# [1] "Wildflowers/Meadows" "Good for kids"       "Rivers"
#
# [[155]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Old growth"
# [4] "Lakes"               "Fall foliage"
#
# [[156]]
# [1] "Mountain views"        "Old growth"            "Summits"
# [4] "Dogs allowed on leash" "Rivers"
#
# [[157]]
# [1] "Mountain views" "Lakes"          "Ridges/passes"
#
# [[158]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash"
#
# [[159]]
# [1] "Summits"
#
# [[160]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [4] "Old growth"            "Lakes"                 "Rivers"
#
# [[161]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"            "Lakes"                 "Ridges/passes"
#
# [[162]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Established campsites"
# [4] "Mountain views"        "Old growth"            "Good for kids"
# [7] "Lakes"
#
# [[163]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Lakes"
#
# [[164]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Waterfalls"          "Dogs not allowed"    "Lakes"
#
# [[165]]
# [1] "Ridges/passes"         "Established campsites" "Mountain views"
# [4] "Old growth"            "Lakes"                 "Fall foliage"
#
# [[166]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Summits"
# [4] "Ridges/passes"
#
# [[167]]
# [1] "Wildflowers/Meadows" "Lakes"
#
# [[168]]
# [1] "Mountain views"   "Wildlife"         "Good for kids"    "Dogs not allowed"
# [5] "Coast"
#
# [[169]]
#  [1] "Wildlife"              "Summits"               "Lakes"
#  [4] "Coast"                 "Wildflowers/Meadows"   "Mountain views"
#  [7] "Dogs allowed on leash" "Waterfalls"            "Old growth"
# [10] "Fall foliage"
#
# [[170]]
# [1] "Wildflowers/Meadows" "Old growth"          "Lakes"
#
# [[171]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
#
# [[172]]
# [1] "Wildlife"     "Fall foliage"
#
# [[173]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Fall foliage"
# [7] "Rivers"
#
# [[174]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Summits"
#
# [[175]]
# [1] "Wildlife" "Summits"
#
# [[176]]
# [1] "Good for kids"         "Lakes"                 "Established campsites"
#
# [[177]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Lakes"
#
# [[178]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Ridges/passes"         "Dogs allowed on leash"
#
# [[179]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Mountain views"        "Summits"               "Dogs allowed on leash"
# [7] "Fall foliage"          "Rivers"
#
# [[180]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Ridges/passes"
#
# [[181]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Rivers"
# [4] "Ridges/passes"
#
# [[182]]
# [1] "Mountain views"        "Wildlife"              "Summits"
# [4] "Dogs allowed on leash"
#
# [[183]]
# [1] "Ridges/passes"         "Wildlife"              "Summits"
# [4] "Lakes"                 "Wildflowers/Meadows"   "Mountain views"
# [7] "Established campsites" "Fall foliage"
#
# [[184]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"
#
# [[185]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Summits"
# [4] "Good for kids"       "Ridges/passes"
#
# [[186]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Summits"             "Lakes"
#
# [[187]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Mountain views"        "Dogs allowed on leash" "Lakes"
# [7] "Fall foliage"
#
# [[188]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Waterfalls"
# [4] "Old growth"          "Dogs not allowed"    "Ridges/passes"
#
# [[189]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Ridges/passes"         "Lakes"
#
# [[190]]
# [1] "Wildflowers/Meadows"   "Established campsites"
#
# [[191]]
# [1] "Mountain views"        "Dogs allowed on leash" "Lakes"
# [4] "Rivers"
#
# [[192]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Ridges/passes"       "Dogs not allowed"    "Summits"
# [7] "Good for kids"
#
# [[193]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Lakes"                 "Dogs allowed on leash"
#
# [[194]]
# [1] "Wildlife"         "Old growth"       "Good for kids"    "Dogs not allowed"
# [5] "Fall foliage"     "Coast"
#
# [[195]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs not allowed"      "Established campsites" "Waterfalls"
# [7] "Old growth"            "Lakes"
#
# [[196]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Fall foliage"          "Ridges/passes"
#
# [[197]]
# [1] "Wildlife"              "Old growth"            "Good for kids"
# [4] "Dogs allowed on leash" "Fall foliage"          "Rivers"
#
# [[198]]
# [1] "Ridges/passes"    "Mountain views"   "Dogs not allowed" "Waterfalls"
# [5] "Lakes"            "Fall foliage"     "Rivers"
#
# [[199]]
# [1] "Mountain views"        "Dogs not allowed"      "Lakes"
# [4] "Established campsites"
#
# [[200]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Established campsites" "Mountain views"        "Summits"
# [7] "Good for kids"         "Fall foliage"
#
# [[201]]
# [1] "Mountain views"        "Dogs allowed on leash" "Established campsites"
# [4] "Waterfalls"            "Old growth"            "Lakes"
#
# [[202]]
# [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
# [4] "Lakes"                 "Rivers"                "Wildflowers/Meadows"
# [7] "Mountain views"        "Established campsites" "Waterfalls"
#
# [[203]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Dogs allowed on leash"
# [7] "Summits"               "Good for kids"         "Lakes"
#
# [[204]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Fall foliage"          "Mountain views"        "Old growth"
# [7] "Summits"               "Waterfalls"
#
# [[205]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"            "Good for kids"         "Lakes"
#
# [[206]]
# [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
# [4] "Lakes"                 "Wildflowers/Meadows"   "Mountain views"
# [7] "Established campsites" "Waterfalls"            "Fall foliage"
#
# [[207]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Rivers"
#
# [[208]]
# [1] "Wildlife"              "Good for kids"         "Dogs allowed on leash"
# [4] "Coast"
#
# [[209]]
#  [1] "Ridges/passes"         "Wildlife"              "Rivers"
#  [4] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
#  [7] "Established campsites" "Waterfalls"            "Old growth"
# [10] "Good for kids"
#
# [[210]]
# [1] "Mountain views"        "Wildlife"              "Waterfalls"
# [4] "Old growth"            "Dogs allowed on leash" "Fall foliage"
# [7] "Rivers"
#
# [[211]]
#  [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
#  [4] "Lakes"                 "Wildflowers/Meadows"   "Mountain views"
#  [7] "Established campsites" "Waterfalls"            "Old growth"
# [10] "Fall foliage"
#
# [[212]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Fall foliage"
# [4] "Ridges/passes"
#
# [[213]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Lakes"
# [4] "Fall foliage"
#
# [[214]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Old growth"          "Lakes"
# [7] "Fall foliage"
#
# [[215]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Good for kids"         "Lakes"
# [7] "Fall foliage"
#
# [[216]]
# [1] "Ridges/passes"         "Wildlife"              "Lakes"
# [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
# [7] "Established campsites" "Old growth"
#
# [[217]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Waterfalls"            "Old growth"            "Summits"
# [7] "Fall foliage"
#
# [[218]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Ridges/passes"         "Summits"               "Good for kids"
#
# [[219]]
# [1] "Wildlife"              "Waterfalls"            "Dogs allowed on leash"
# [4] "Old growth"            "Lakes"                 "Rivers"
#
# [[220]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Good for kids"
# [4] "Dogs not allowed"    "Rivers"
#
# [[221]]
# [1] "Mountain views"        "Dogs not allowed"      "Rivers"
# [4] "Established campsites" "Ridges/passes"
#
# [[222]]
# [1] "Ridges/passes"    "Wildlife"         "Dogs not allowed" "Lakes"
# [5] "Rivers"
#
# [[223]]
# [1] "Dogs not allowed"      "Rivers"                "Lakes"
# [4] "Established campsites" "Waterfalls"
#
# [[224]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Mountain views"        "Old growth"            "Waterfalls"
# [7] "Lakes"                 "Rivers"
#
# [[225]]
#  [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
#  [4] "Lakes"                 "Rivers"                "Wildflowers/Meadows"
#  [7] "Mountain views"        "Established campsites" "Waterfalls"
# [10] "Old growth"
#
# [[226]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Summits"
#
# [[227]]
# [1] "Mountain views" "Summits"        "Ridges/passes"
#
# [[228]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Established campsites" "Mountain views"        "Waterfalls"
# [7] "Lakes"
#
# [[229]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Lakes"                 "Established campsites"
#
# [[230]]
#  [1] "Wildlife"              "Summits"               "Lakes"
#  [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
#  [7] "Dogs allowed on leash" "Established campsites" "Waterfalls"
# [10] "Fall foliage"
#
# [[231]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Waterfalls"            "Good for kids"
# [7] "Fall foliage"
#
# [[232]]
# [1] "Mountain views"        "Dogs allowed on leash" "Lakes"
#
# [[233]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Dogs not allowed"    "Summits"
# [7] "Good for kids"       "Fall foliage"
#
# [[234]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Good for kids"
#
# [[235]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Old growth"
# [4] "Summits"
#
# [[236]]
# [1] "Mountain views"        "Dogs allowed on leash" "Established campsites"
# [4] "Waterfalls"            "Old growth"            "Summits"
# [7] "Lakes"
#
# [[237]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Old growth"
# [4] "Dogs allowed on leash" "Ridges/passes"
#
# [[238]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Lakes"
#
# [[239]]
# [1] "Wildlife"              "Old growth"            "Summits"
# [4] "Good for kids"         "Dogs allowed on leash" "Rivers"
#
# [[240]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Good for kids"         "Dogs allowed on leash" "Fall foliage"
# [7] "Rivers"
#
# [[241]]
# [1] "Ridges/passes"         "Wildlife"              "Dogs allowed on leash"
# [4] "Fall foliage"
#
# [[242]]
# [1] "Dogs allowed on leash" "Old growth"            "Lakes"
# [4] "Established campsites"
#
# [[243]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Waterfalls"
#
# [[244]]
# [1] "Dogs not allowed"      "Coast"                 "Good for kids"
# [4] "Established campsites" "Rivers"
#
# [[245]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Dogs allowed on leash"
# [7] "Rivers"
#
# [[246]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Mountain views"        "Old growth"            "Waterfalls"
# [7] "Good for kids"         "Lakes"                 "Fall foliage"
#
# [[247]]
# [1] "Ridges/passes"         "Established campsites" "Mountain views"
# [4] "Lakes"                 "Fall foliage"          "Rivers"
#
# [[248]]
# [1] "Mountain views" "Old growth"     "Rivers"
#
# [[249]]
# [1] "Wildflowers/Meadows"   "Dogs not allowed"      "Established campsites"
# [4] "Old growth"            "Lakes"                 "Rivers"
#
# [[250]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Old growth"            "Dogs allowed on leash"
# [7] "Fall foliage"
#
# [[251]]
# [1] "Ridges/passes"         "Wildlife"              "Rivers"
# [4] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [7] "Waterfalls"            "Old growth"
#
# [[252]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Dogs not allowed"    "Summits"
# [7] "Lakes"
#
# [[253]]
# [1] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [4] "Rivers"
#
# [[254]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Waterfalls"          "Old growth"          "Fall foliage"
#
# [[255]]
# [1] "Old growth"            "Good for kids"         "Dogs allowed on leash"
#
# [[256]]
# [1] "Mountain views" "Ridges/passes"
#
# [[257]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Mountain views"        "Dogs allowed on leash" "Waterfalls"
# [7] "Good for kids"         "Lakes"
#
# [[258]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Summits"               "Fall foliage"          "Rivers"
#
# [[259]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs not allowed"      "Good for kids"
# [7] "Lakes"
#
# [[260]]
# [1] "Mountain views"   "Dogs not allowed" "Lakes"            "Fall foliage"
# [5] "Ridges/passes"
#
# [[261]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Good for kids"
#
# [[262]]
# [1] "Wildflowers/Meadows" "Fall foliage"        "Rivers"
#
# [[263]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Summits"               "Dogs allowed on leash"
#
# [[264]]
# [1] "Ridges/passes"         "Wildlife"              "Summits"
# [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
# [7] "Dogs allowed on leash" "Established campsites" "Old growth"
#
# [[265]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Ridges/passes"         "Dogs allowed on leash" "Lakes"
#
# [[266]]
# [1] "Dogs allowed on leash" "Wildlife"              "Lakes"
# [4] "Fall foliage"
#
# [[267]]
# [1] "Established campsites" "Rivers"
#
# [[268]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Old growth"          "Good for kids"       "Dogs not allowed"
# [7] "Rivers"
#
# [[269]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Ridges/passes"         "Summits"
#
# [[270]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Rivers"                "Ridges/passes"
#
# [[271]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Dogs not allowed"    "Waterfalls"          "Old growth"
# [7] "Good for kids"       "Lakes"               "Rivers"
#
# [[272]]
# [1] "Mountain views"        "Dogs allowed on leash" "Waterfalls"
# [4] "Good for kids"         "Lakes"                 "Fall foliage"
#
# [[273]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Established campsites"
# [4] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [7] "Rivers"
#
# [[274]]
# [1] "Mountain views"        "Wildlife"              "Established campsites"
# [4] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [7] "Rivers"
#
# [[275]]
# [1] "Dogs allowed on leash" "Good for kids"         "Lakes"
# [4] "Established campsites" "Waterfalls"
#
# [[276]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Dogs allowed on leash" "Rivers"
#
# [[277]]
# [1] "Dogs allowed on leash" "Old growth"            "Wildlife"
# [4] "Lakes"
#
# [[278]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash"
#
# [[279]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Lakes"
#
# [[280]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Old growth"            "Summits"               "Fall foliage"
#
# [[281]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Ridges/passes"         "Good for kids"
# [7] "Rivers"
#
# [[282]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Summits"
# [7] "Dogs allowed on leash"
#
# [[283]]
# [1] "Dogs not allowed" "Old growth"       "Summits"          "Wildlife"
#
# [[284]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Old growth"            "Good for kids"
# [7] "Lakes"
#
# [[285]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Lakes"                 "Established campsites"
#
# [[286]]
# [1] "Dogs allowed on leash" "Good for kids"         "Rivers"
#
# [[287]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs not allowed"      "Established campsites" "Old growth"
# [7] "Good for kids"         "Lakes"
#
# [[288]]
# [1] "Old growth"            "Rivers"                "Dogs allowed on leash"
# [4] "Waterfalls"
#
# [[289]]
# [1] "Wildflowers/Meadows" "Wildlife"
#
# [[290]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Summits"
# [7] "Rivers"
#
# [[291]]
# [1] "Mountain views" "Fall foliage"   "Ridges/passes"
#
# [[292]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Fall foliage"          "Ridges/passes"
#
# [[293]]
# [1] "Dogs not allowed"      "Good for kids"         "Established campsites"
# [4] "Rivers"
#
# [[294]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Waterfalls"            "Dogs not allowed"
# [7] "Lakes"                 "Rivers"
#
# [[295]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Old growth"
# [4] "Rivers"
#
# [[296]]
# [1] "Mountain views"        "Old growth"            "Dogs allowed on leash"
#
# [[297]]
# [1] "Wildlife"              "Dogs not allowed"      "Established campsites"
# [4] "Old growth"            "Coast"                 "Lakes"
# [7] "Rivers"
#
# [[298]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs allowed on leash" "Lakes"
# [7] "Fall foliage"          "Rivers"
#
# [[299]]
# [1] "Lakes"                 "Established campsites"
#
# [[300]]
# [1] "Dogs allowed on leash" "Fall foliage"
#
# [[301]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Waterfalls"
# [4] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [7] "Fall foliage"
#
# [[302]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Summits"
#
# [[303]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Mountain views"        "Old growth"            "Waterfalls"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[304]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Summits"               "Fall foliage"
#
# [[305]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Waterfalls"
# [4] "Old growth"          "Summits"             "Rivers"
#
# [[306]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Summits"               "Lakes"
#
# [[307]]
# [1] "Ridges/passes"       "Wildlife"            "Summits"
# [4] "Lakes"               "Wildflowers/Meadows" "Mountain views"
# [7] "Old growth"          "Fall foliage"
#
# [[308]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Ridges/passes"       "Dogs not allowed"    "Lakes"
#
# [[309]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Summits"
# [4] "Rivers"              "Waterfalls"
#
# [[310]]
# [1] "Mountain views"        "Dogs allowed on leash" "Ridges/passes"
#
# [[311]]
# [1] "Mountain views" "Wildlife"       "Good for kids"  "Lakes"
# [5] "Ridges/passes"
#
# [[312]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Old growth"
# [4] "Wildlife"
#
# [[313]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Dogs not allowed"    "Summits"             "Lakes"
#
# [[314]]
#  [1] "Ridges/passes"         "Dogs not allowed"      "Lakes"
#  [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
#  [7] "Established campsites" "Waterfalls"            "Old growth"
# [10] "Fall foliage"
#
# [[315]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Summits"
# [7] "Good for kids"         "Dogs allowed on leash"
#
# [[316]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Old growth"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[317]]
# [1] "Old growth"
#
# [[318]]
# [1] "Wildflowers/Meadows" "Fall foliage"
#
# [[319]]
# [1] "Lakes"                 "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Fall foliage"
#
# [[320]]
# [1] "Ridges/passes"         "Wildlife"              "Wildflowers/Meadows"
# [4] "Mountain views"        "Established campsites" "Waterfalls"
# [7] "Old growth"            "Good for kids"         "Fall foliage"
#
# [[321]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs allowed on leash" "Rivers"
#
# [[322]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Wildlife"
# [4] "Lakes"                 "Rivers"
#
# [[323]]
# [1] "Mountain views"        "Dogs allowed on leash" "Ridges/passes"
# [4] "Old growth"            "Lakes"                 "Fall foliage"
#
# [[324]]
# [1] "Dogs allowed on leash" "Old growth"            "Summits"
# [4] "Wildlife"
#
# [[325]]
# [1] "Mountain views"   "Dogs not allowed" "Lakes"            "Ridges/passes"
#
# [[326]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Old growth"
# [4] "Lakes"                 "Established campsites"
#
# [[327]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Established campsites"
# [4] "Old growth"            "Good for kids"         "Rivers"
#
# [[328]]
# [1] "Ridges/passes"         "Wildlife"              "Lakes"
# [4] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [7] "Established campsites" "Waterfalls"            "Old growth"
#
# [[329]]
# [1] "Old growth"            "Dogs allowed on leash" "Rivers"
#
# [[330]]
# [1] "Wildflowers/Meadows" "Lakes"               "Fall foliage"
# [4] "Waterfalls"
#
# [[331]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Established campsites"
# [4] "Old growth"            "Dogs allowed on leash" "Rivers"
#
# [[332]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [4] "Summits"               "Good for kids"         "Rivers"
#
# [[333]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Dogs allowed on leash"
# [4] "Rivers"
#
# [[334]]
# [1] "Dogs allowed on leash" "Wildlife"              "Lakes"
#
# [[335]]
# [1] "Mountain views"        "Dogs allowed on leash" "Lakes"
# [4] "Fall foliage"          "Ridges/passes"
#
# [[336]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs allowed on leash" "Good for kids"
# [7] "Lakes"                 "Fall foliage"          "Rivers"
#
# [[337]]
# [1] "Mountain views" "Lakes"
#
# [[338]]
# ...
# [4] "Old growth"            "Coast"                 "Good for kids"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[948]]
# [1] "Mountain views" "Wildlife"       "Summits"        "Good for kids"
#
# [[949]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Wildlife"
# [4] "Lakes"               "Rivers"
#
# [[950]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Old growth"
# [4] "Good for kids"         "Dogs allowed on leash" "Rivers"
#
# [[951]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Dogs allowed on leash" "Dogs not allowed"      "Lakes"
#
# [[952]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Dogs allowed on leash"
# [4] "Good for kids"         "Lakes"                 "Coast"
#
# [[953]]
# [1] "Dogs allowed on leash" "Summits"               "Good for kids"
#
# [[954]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Lakes"                 "Rivers"
#
# [[955]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Dogs not allowed"
# [4] "Old growth"          "Good for kids"       "Lakes"
#
# [[956]]
# [1] "Ridges/passes"         "Summits"               "Lakes"
# [4] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [7] "Waterfalls"            "Old growth"
#
# [[957]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Old growth"          "Summits"
# [7] "Fall foliage"
#
# [[958]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Ridges/passes"
# [4] "Dogs not allowed"    "Summits"             "Fall foliage"
#
# [[959]]
# [1] "Mountain views"        "Dogs allowed on leash" "Coast"
# [4] "Waterfalls"
#
# [[960]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Good for kids"
# [4] "Dogs allowed on leash" "Coast"
#
# [[961]]
# [1] "Mountain views"        "Old growth"            "Good for kids"
# [4] "Dogs allowed on leash" "Fall foliage"
#
# [[962]]
# [1] "Dogs allowed on leash" "Summits"               "Fall foliage"
#
# [[963]]
# [1] "Dogs allowed on leash" "Good for kids"         "Fall foliage"
# [4] "Waterfalls"
#
# [[964]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Summits"
# [4] "Good for kids"         "Dogs allowed on leash"
#
# [[965]]
# [1] "Old growth" "Wildlife"   "Lakes"
#
# [[966]]
# [1] "Wildlife"         "Dogs not allowed" "Rivers"
#
# [[967]]
#  [1] "Ridges/passes"         "Wildlife"              "Dogs not allowed"
#  [4] "Summits"               "Lakes"                 "Rivers"
#  [7] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [10] "Waterfalls"            "Old growth"            "Fall foliage"
#
# [[968]]
# [1] "Mountain views"        "Established campsites" "Ridges/passes"
# [4] "Dogs not allowed"      "Lakes"                 "Fall foliage"
#
# [[969]]
# [1] "Mountain views" "Waterfalls"     "Lakes"          "Ridges/passes"
#
# [[970]]
# [1] "Mountain views"        "Old growth"            "Good for kids"
# [4] "Wildlife"              "Dogs allowed on leash"
#
# [[971]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Rivers"
#
# [[972]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Established campsites"
# [4] "Ridges/passes"         "Dogs not allowed"      "Lakes"
#
# [[973]]
# [1] "Mountain views" "Old growth"     "Summits"        "Good for kids"
# [5] "Fall foliage"
#
# [[974]]
#  [1] "Wildlife"              "Summits"               "Lakes"
#  [4] "Rivers"                "Wildflowers/Meadows"   "Mountain views"
#  [7] "Dogs allowed on leash" "Established campsites" "Waterfalls"
# [10] "Old growth"            "Good for kids"         "Fall foliage"
#
# [[975]]
# [1] "Mountain views"        "Dogs allowed on leash" "Summits"
# [4] "Fall foliage"          "Established campsites"
#
# [[976]]
# [1] "Mountain views"        "Old growth"            "Wildlife"
# [4] "Dogs allowed on leash" "Ridges/passes"
#
# [[977]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Good for kids"
# [7] "Dogs allowed on leash" "Rivers"
#
# [[978]]
# [1] "Ridges/passes" "Summits"
#
# [[979]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Established campsites" "Mountain views"        "Lakes"
# [7] "Rivers"
#
# [[980]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Old growth"
# [4] "Summits"             "Ridges/passes"
#
# [[981]]
# [1] "Wildflowers/Meadows" "Good for kids"
#
# [[982]]
# [1] "Wildflowers/Meadows"   "Old growth"            "Good for kids"
# [4] "Dogs allowed on leash" "Fall foliage"
#
# [[983]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Established campsites"
# [4] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [7] "Fall foliage"          "Rivers"
#
# [[984]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Waterfalls"            "Dogs allowed on leash" "Old growth"
# [7] "Lakes"                 "Fall foliage"
#
# [[985]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Established campsites"
# [4] "Mountain views"        "Old growth"            "Lakes"
# [7] "Rivers"
#
# [[986]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Summits"
# [4] "Lakes"
#
# [[987]]
# [1] "Ridges/passes"         "Dogs allowed on leash" "Lakes"
# [4] "Established campsites" "Rivers"
#
# [[988]]
# [1] "Mountain views"   "Old growth"       "Good for kids"    "Dogs not allowed"
#
# [[989]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Old growth"
# [4] "Lakes"                 "Dogs allowed on leash"
#
# [[990]]
# [1] "Mountain views"        "Lakes"                 "Established campsites"
# [4] "Fall foliage"
#
# [[991]]
#  [1] "Ridges/passes"         "Wildlife"              "Summits"
#  [4] "Lakes"                 "Rivers"                "Wildflowers/Meadows"
#  [7] "Mountain views"        "Established campsites" "Waterfalls"
# [10] "Old growth"
#
# [[992]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Good for kids"         "Dogs allowed on leash" "Rivers"
#
# [[993]]
# [1] "Wildflowers/Meadows" "Dogs not allowed"    "Wildlife"
# [4] "Good for kids"       "Lakes"
#
# [[994]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Fall foliage"
#
# [[995]]
# [1] "Wildlife"              "Established campsites" "Waterfalls"
# [4] "Dogs not allowed"      "Rivers"                "Coast"
#
# [[996]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Mountain views"        "Old growth"            "Good for kids"
# [7] "Lakes"                 "Fall foliage"          "Rivers"
#
# [[997]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Lakes"
# [4] "Established campsites" "Rivers"
#
# [[998]]
# [1] "Wildflowers/Meadows" "Summits"             "Fall foliage"
#
# [[999]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Good for kids"
# [4] "Lakes"                 "Established campsites"
#
# [[1000]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Old growth"            "Lakes"
#
# [[1001]]
# [1] "Mountain views"        "Wildlife"              "Dogs allowed on leash"
# [4] "Summits"               "Lakes"                 "Fall foliage"
#
# [[1002]]
# [1] "Mountain views" "Old growth"     "Waterfalls"     "Wildlife"
# [5] "Lakes"
#
# [[1003]]
# [1] "Mountain views"        "Wildlife"              "Summits"
# [4] "Dogs allowed on leash" "Ridges/passes"
#
# [[1004]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Old growth"            "Lakes"                 "Rivers"
#
# [[1005]]
# [1] "Dogs not allowed" "Old growth"       "Good for kids"    "Wildlife"
# [5] "Waterfalls"
#
# [[1006]]
# [1] "Dogs allowed on leash" "Waterfalls"            "Old growth"
# [4] "Good for kids"         "Lakes"                 "Fall foliage"
#
# [[1007]]
# [1] "Old growth"            "Dogs allowed on leash" "Waterfalls"
#
# [[1008]]
# [1] "Mountain views" "Old growth"     "Good for kids"
#
# [[1009]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Dogs allowed on leash" "Lakes"                 "Fall foliage"
#
# [[1010]]
# [1] "Mountain views"        "Old growth"            "Lakes"
# [4] "Established campsites"
#
# [[1011]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Old growth"            "Dogs allowed on leash" "Fall foliage"
#
# [[1012]]
# [1] "Mountain views"        "Wildlife"              "Established campsites"
# [4] "Waterfalls"            "Dogs allowed on leash" "Lakes"
# [7] "Rivers"
#
# [[1013]]
# [1] "Mountain views"        "Lakes"                 "Established campsites"
# [4] "Ridges/passes"
#
# [[1014]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Waterfalls"            "Good for kids"         "Dogs allowed on leash"
# [7] "Fall foliage"          "Rivers"
#
# [[1015]]
# [1] "Mountain views"        "Wildlife"              "Lakes"
# [4] "Dogs allowed on leash" "Ridges/passes"
#
# [[1016]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Dogs not allowed"      "Summits"
# [7] "Lakes"
#
# [[1017]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Wildlife"
# [4] "Established campsites" "Mountain views"        "Old growth"
#
# [[1018]]
# [1] "Wildflowers/Meadows"   "Old growth"            "Good for kids"
# [4] "Dogs allowed on leash"
#
# [[1019]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Good for kids"
#
# [[1020]]
# [1] "Ridges/passes"         "Wildlife"              "Summits"
# [4] "Dogs allowed on leash" "Coast"
#
# [[1021]]
# [1] "Wildflowers/Meadows"   "Old growth"            "Dogs allowed on leash"
# [4] "Waterfalls"
#
# [[1022]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Dogs allowed on leash"
# [4] "Coast"
#
# [[1023]]
# [1] "Mountain views"        "Dogs allowed on leash" "Good for kids"
# [4] "Coast"
#
# [[1024]]
# [1] "Wildflowers/Meadows"   "Old growth"            "Dogs allowed on leash"
# [4] "Fall foliage"
#
# [[1025]]
# [1] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [4] "Fall foliage"          "Waterfalls"
#
# [[1026]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Waterfalls"
# [4] "Dogs not allowed"    "Lakes"               "Fall foliage"
#
# [[1027]]
# [1] "Wildflowers/Meadows" "Mountain views"      "Summits"
# [4] "Lakes"               "Fall foliage"
#
# [[1028]]
# [1] "Ridges/passes"    "Dogs not allowed" "Lakes"
#
# [[1029]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Mountain views"      "Old growth"          "Summits"
# [7] "Lakes"
#
# [[1030]]
# [1] "Wildflowers/Meadows"   "Dogs allowed on leash" "Established campsites"
# [4] "Waterfalls"            "Old growth"            "Fall foliage"
#
# [[1031]]
# [1] "Waterfalls"
#
# [[1032]]
# [1] "Wildflowers/Meadows"   "Lakes"                 "Established campsites"
# [4] "Waterfalls"
#
# [[1033]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Wildlife"
# [4] "Established campsites" "Ridges/passes"         "Dogs not allowed"
#
# [[1034]]
# [1] "Mountain views"        "Wildlife"              "Dogs allowed on leash"
# [4] "Old growth"            "Lakes"
#
# [[1035]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Established campsites"
# [4] "Mountain views"        "Waterfalls"            "Rivers"
#
# [[1036]]
# [1] "Dogs not allowed" "Old growth"       "Good for kids"    "Wildlife"
#
# [[1037]]
# [1] "Old growth"            "Good for kids"         "Wildlife"
# [4] "Established campsites" "Rivers"
#
# [[1038]]
# [1] "Mountain views"        "Established campsites"
#
# [[1039]]
# [1] "Old growth"            "Rivers"                "Established campsites"
# [4] "Waterfalls"
#
# [[1040]]
# [1] "Ridges/passes" "Old growth"    "Rivers"
#
# [[1041]]
# [1] "Mountain views"        "Established campsites" "Rivers"
#
# [[1042]]
# [1] "Mountain views"        "Wildlife"              "Lakes"
# [4] "Established campsites" "Rivers"
#
# [[1043]]
# [1] "Wildflowers/Meadows" "Wildlife"            "Dogs not allowed"
# [4] "Old growth"          "Lakes"               "Rivers"
#
# [[1044]]
# [1] "Mountain views" "Old growth"     "Summits"        "Good for kids"
# [5] "Lakes"
#
# [[1045]]
# [1] "Rivers"     "Lakes"      "Waterfalls"
#
# [[1046]]
# [1] "Mountain views" "Old growth"     "Wildlife"       "Rivers"
#
# [[1047]]
# [1] "Ridges/passes" "Good for kids" "Lakes"
#
# [[1048]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites" "Summits"               "Lakes"
#
# [[1049]]
# [1] "Mountain views"        "Good for kids"         "Established campsites"
#
# [[1050]]
# [1] "Wildflowers/Meadows" "Old growth"          "Dogs not allowed"
# [4] "Waterfalls"
#
# [[1051]]
# [1] "Mountain views" "Wildlife"       "Lakes"          "Ridges/passes"
#
# [[1052]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
#
# [[1053]]
# [1] "Mountain views" "Old growth"     "Good for kids"  "Lakes"
# [5] "Waterfalls"
#
# [[1054]]
# [1] "Dogs allowed on leash" "Old growth"            "Good for kids"
# [4] "Wildlife"              "Lakes"
#
# [[1055]]
# [1] "Ridges/passes" "Lakes"
#
# [[1056]]
# [1] "Wildlife"      "Good for kids"
#
# [[1057]]
# [1] "Mountain views" "Wildlife"       "Summits"        "Lakes"
# [5] "Ridges/passes"
#
# [[1058]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Lakes"
# [4] "Established campsites"
#
# [[1059]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Old growth"
# [4] "Dogs allowed on leash" "Fall foliage"
#
# [[1060]]
# [1] "Old growth"            "Dogs allowed on leash" "Established campsites"
#
# [[1061]]
# [1] "Old growth" "Wildlife"   "Rivers"
#
# [[1062]]
# [1] "Wildflowers/Meadows"   "Old growth"            "Established campsites"
#
# [[1063]]
# [1] "Mountain views" "Good for kids"  "Lakes"
#
# [[1064]]
# [1] "Wildflowers/Meadows" "Ridges/passes"       "Wildlife"
# [4] "Dogs not allowed"    "Mountain views"      "Old growth"
# [7] "Lakes"
#
# [[1065]]
# [1] "Wildflowers/Meadows"   "Wildlife"              "Established campsites"
# [4] "Rivers"
#
# [[1066]]
# [1] "Old growth"            "Good for kids"         "Dogs allowed on leash"
# [4] "Established campsites"
#
# [[1067]]
# [1] "Dogs allowed on leash" "Old growth"            "Lakes"
# [4] "Fall foliage"
#
# [[1068]]
# [1] "Mountain views" "Old growth"     "Ridges/passes"
#
# [[1069]]
# [1] "Old growth"       "Good for kids"    "Dogs not allowed" "Rivers"
#
# [[1070]]
# [1] "Wildflowers/Meadows"   "Ridges/passes"         "Dogs allowed on leash"
# [4] "Lakes"
#
# [[1071]]
# [1] "Wildflowers/Meadows"   "Mountain views"        "Dogs allowed on leash"
# [4] "Established campsites"

# %% [markdown]
# Question 4. What is the most common rating of a route?

# %%
# %%R
# head(clean_hike_trails$rating, 6)
# Out:
# [1] 3.67 4.16 3.68 3.92 4.14 3.14

# %%
# %%R
# install.packages("DescTools")
# library("DescTools")
# Out:
# R[write to console]: устанавливаю также зависимости ‘proxy’, ‘rootSolve’, ‘e1071’, ‘lmom’, ‘mvtnorm’, ‘expm’, ‘Rcpp’, ‘Exact’, ‘gld’, ‘readxl’, ‘BH’
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/proxy_0.4-27.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 74622 bytes (72 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 72 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/rootSolve_1.8.2.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 526589 bytes (514 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 514 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/e1071_1.7-12.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 326251 bytes (318 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 318 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/lmom_2.9.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 347594 bytes (339 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 339 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/mvtnorm_1.1-3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 166421 bytes (162 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 162 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/expm_0.999-6.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 151884 bytes (148 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 148 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/Rcpp_1.0.9.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2957812 bytes (2.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.8 MB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/Exact_3.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 46201 bytes (45 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 45 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/gld_2.6.6.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 54770 bytes (53 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 53 KB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/readxl_1.4.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2090383 bytes (2.0 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.0 MB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/BH_1.78.0-0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 13269768 bytes (12.7 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 12.7 MB
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/src/contrib/DescTools_0.99.47.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2634629 bytes (2.5 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.5 MB
#
#
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘proxy’ ...
# ** пакет ‘proxy’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c apply.c -o apply.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c arrayIndex.c -o arrayIndex.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c distance.c -o distance.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c dll.c -o dll.o
# distance.c:429:2: warning: add explicit braces to avoid dangling else [-Wdangling-else]
#         else
#         ^
# distance.c:476:2: warning: add explicit braces to avoid dangling else [-Wdangling-else]
#         else
#         ^
# 2 warnings generated.
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c util.c -o util.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o proxy.so apply.o arrayIndex.o distance.o dll.o util.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-proxy/00new/proxy/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (proxy)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘rootSolve’ ...
# ** пакет ‘rootSolve’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c R_init_rootSolve.c -o R_init_rootSolve.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c call_runsteady.c -o call_runsteady.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c call_steady.c -o call_steady.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c call_stsparse.c -o call_stsparse.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dlinpk.f -o dlinpk.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dsparsk.f -o dsparsk.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c lsodes.f -o lsodes.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c sparse.f -o sparse.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c sparsecoeff.f -o sparsecoeff.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c sparsekit.f -o sparsekit.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c steady.f -o steady.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c steady_utils.c -o steady_utils.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c testMap.f -o testMap.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o rootSolve.so R_init_rootSolve.o call_runsteady.o call_steady.o call_stsparse.o dlinpk.o dsparsk.o lsodes.o sparse.o sparsecoeff.o sparsekit.o steady.o steady_utils.o testMap.o -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-rootSolve/00new/rootSolve/libs
# ** R
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rootSolve)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘lmom’ ...
# ** пакет ‘lmom’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c d1mach.f -o d1mach.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqagie.f -o dqagie.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqagse.f -o dqagse.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqelg.f -o dqelg.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqk15i.f -o dqk15i.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqk21.f -o dqk21.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c dqpsrt.f -o dqpsrt.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c init.c -o init.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c lmomc.c -o lmomc.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c lmoments.f -o lmoments.o
# lmoments.f:288:72:
#
#   288 |    10 XMOM(J)=TWO/DFLOAT(J*(J-1))
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:448:72:
#
#   448 |    10 XMOM(I)=ZMOM(I)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:624:72:
#
#   624 |    10 SUM=SUM*GG+Z(K,M)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:712:72:
#
#   712 |     2 XMOM(I)=ZMOM(I)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 2 at (1)
# lmoments.f:739:72:
#
#   739 |    10 SUM(M)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:755:72:
#
#   755 |    20 SUM(M)=SUM(M)+E*P
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 20 at (1)
# lmoments.f:758:72:
#
#   758 |    40 EST(M)=SUM(M)*XINC
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 40 at (1)
# lmoments.f:764:72:
#
#   764 |    50 ESTX(M)=EST(M)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 50 at (1)
# lmoments.f:780:72:
#
#   780 |    60 SUM(M)=SUM(M)+E*P
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 60 at (1)
# lmoments.f:797:72:
#
#   797 |   110 XMOM(M)=CONST*EST(M)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 110 at (1)
# lmoments.f:928:72:
#
#   928 |    10 XMOM(J)=ZMOM(J)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:1004:72:
#
#  1004 |    20 BETA(IR)=DEXP(ARG)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 20 at (1)
# lmoments.f:1011:72:
#
#  1011 |    40 BETA(IR)=DEXP(DLGAM-G*DLOG(R))*(ONE-HALF*H*G*(ONE+G)/R)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 40 at (1)
# lmoments.f:1020:72:
#
#  1020 |    60 BETA(IR)=DEXP(ARG)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 60 at (1)
# lmoments.f:1027:72:
#
#  1027 |    80 BETA(IR)=EU+DLOG(-H)+DIGAMD(-R/H)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 80 at (1)
# lmoments.f:1034:72:
#
#  1034 |   100 BETA(IR)=EU+DLOG(R)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 100 at (1)
# lmoments.f:1041:72:
#
#  1041 |   120 BETA(IR)=EU+DLOG(H)+DIGAMD(ONE+R/H)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 120 at (1)
# lmoments.f:1135:72:
#
#  1135 |    10 XMOM(M)=ZMOM(M)
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:1819:72:
#
#  1819 |    10 PARA(I)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# lmoments.f:2114:72:
#
#  2114 |  1010 PARA(I)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 1010 at (1)
# lmoments.f:2234:72:
#
#  2234 |  1010 PARA(I)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 1010 at (1)
# lmoments.f:2333:72:
#
#  2333 |  1010 PARA(I)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 1010 at (1)
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c samlm.f -o samlm.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o lmom.so d1mach.o dqagie.o dqagse.o dqelg.o dqk15i.o dqk21.o dqpsrt.o init.o lmomc.o lmoments.o samlm.o -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# samlm.f:39:72:
#
#    39 |    10 XMOM(J)=ZERO
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 10 at (1)
# samlm.f:106:72:
#
#   106 |    80 XMOM(J)=XMOM(J)*AMULT
#       |                                                                        1
# Warning: Fortran 2018 deleted feature: DO termination statement which is not END DO or CONTINUE with label 80 at (1)
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-lmom/00new/lmom/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (lmom)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘mvtnorm’ ...
# ** пакет ‘mvtnorm’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c C_FORTRAN_interface.c -o C_FORTRAN_interface.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c miwa.c -o miwa.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c mvt.f -o mvt.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c mvtnorm-init.c -o mvtnorm-init.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c tvpack.f -o tvpack.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o mvtnorm.so C_FORTRAN_interface.o miwa.o mvt.o mvtnorm-init.o tvpack.o -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# ld: warning: could not create compact unwind for _mvkbrv_: stack subq instruction is too different from dwarf stack size
# ld: warning: could not create compact unwind for _master.0.mvsubr_.constprop.0: stack subq instruction is too different from dwarf stack size
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-mvtnorm/00new/mvtnorm/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mvtnorm)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘expm’ ...
# ** пакет ‘expm’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c R_dgebal.c -o R_dgebal.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c expm-eigen.c -o expm-eigen.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c expm.c -o expm.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c init.c -o init.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c logm-eigen.c -o logm-eigen.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c matexp.f -o matexp.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c matexp_MH09.c -o matexp_MH09.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c matpow.c -o matpow.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c matrexp.f -o matrexp.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c matrexpO.f -o matrexpO.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c mexp-common.f -o mexp-common.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o expm.so R_dgebal.o expm-eigen.o expm.o init.o logm-eigen.o matexp.o matexp_MH09.o matpow.o matrexp.o matrexpO.o mexp-common.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lRlapack -L/usr/local/opt/openblas/lib -lopenblas -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-expm/00new/expm/libs
# ** R
# ** data
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (expm)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘Rcpp’ ...
# ** пакет ‘Rcpp’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c api.cpp -o api.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c attributes.cpp -o attributes.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c barrier.cpp -o barrier.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c date.cpp -o date.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c module.cpp -o module.o
# clang++ -std=gnu++14 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -I../inst/include/  -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c rcpp_init.cpp -o rcpp_init.o
# clang++ -std=gnu++14 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o Rcpp.so api.o attributes.o barrier.o date.o module.o rcpp_init.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-Rcpp/00new/Rcpp/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (Rcpp)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘readxl’ ...
# ** пакет ‘readxl’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -Iunix -I. -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/progress/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c cpp11.cpp -o cpp11.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -Iunix -I. -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/progress/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c XlsWorkBook.cpp -o XlsWorkBook.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -Iunix -I. -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/progress/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c XlsxWorkBook.cpp -o XlsxWorkBook.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -Iunix -I. -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/progress/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c zip.cpp -o zip.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG -Iunix -I. -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/cpp11/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/progress/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c Read.cpp -o Read.o
# ...
# clang++ -std=gnu++14 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o e1071.so Rsvm.o cmeans.o cshell.o floyd.o init.o svm.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-e1071/00new/e1071/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (e1071)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘Exact’ ...
# ** пакет ‘Exact’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (Exact)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘gld’ ...
# ** пакет ‘gld’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c fit_fkml.c -o fit_fkml.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c gld.fm5.fx.c -o gld.fm5.fx.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c gld.fmkl.fx.c -o gld.fmkl.fx.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c gld.rs.fx.c -o gld.rs.fx.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c gld.vsk.fx.c -o gld.vsk.fx.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG   -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c gld_init.c -o gld_init.o
# clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o gld.so fit_fkml.o gld.fm5.fx.o gld.fmkl.fx.o gld.rs.fx.o gld.vsk.fx.o gld_init.o -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-gld/00new/gld/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** testing if installed package keeps a record of temporary installation path
# * DONE (gld)
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# * installing *source* package ‘DescTools’ ...
# ** пакет ‘DescTools’ удачно распакован, MD5 sums проверены
# ** using staged installation
# ** libs
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c ADinf.c -o ADinf.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c AnDarl.c -o AnDarl.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c RcppExports.cpp -o RcppExports.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c aux_fct.cpp -o aux_fct.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c between.c -o between.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c cidxcn.f -o cidxcn.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c conc.c -o conc.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c exactsum.c -o exactsum.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c extremes.cpp -o extremes.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c fdwilcox.c -o fdwilcox.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c fpow.c -o fpow.o
# clang++ -std=gnu++11 -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -g -O2  -c gompertz.cpp -o gompertz.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c hoeffd.f -o hoeffd.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c init.c -o init.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c jtpdf.f -o jtpdf.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c ks.c -o ks.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c moments.c -o moments.o
# /usr/local/opt/gcc/bin/gfortran -fno-optimize-sibling-calls  -fPIC  -g -O2  -c pan.f -o pan.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c pointinpolygon.c -o pointinpolygon.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c roman2int.c -o roman2int.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c tbrm.c -o tbrm.o
# clang -I"/usr/local/Cellar/r/4.2.1_4/lib/R/include" -DNDEBUG  -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/Rcpp/include' -I'/usr/local/Cellar/r/4.2.1_4/lib/R/library/BH/include' -I/usr/local/opt/gettext/include -I/usr/local/opt/readline/include -I/usr/local/opt/xz/include -I/usr/local/include   -fPIC  -Wno-implicit-function-declaration  -c wgt_himed.c -o wgt_himed.o
# clang++ -std=gnu++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -L/usr/local/opt/gettext/lib -L/usr/local/opt/readline/lib -L/usr/local/opt/xz/lib -L/usr/local/lib -o DescTools.so ADinf.o AnDarl.o RcppExports.o aux_fct.o between.o cidxcn.o conc.o exactsum.o extremes.o fdwilcox.o fpow.o gompertz.o hoeffd.o init.o jtpdf.o ks.o moments.o pan.o pointinpolygon.o roman2int.o tbrm.o wgt_himed.o -L/usr/local/opt/gcc/lib/gcc/current/gcc/x86_64-apple-darwin20/12 -L/usr/local/opt/gcc/lib/gcc/current/gcc -L/usr/local/opt/gcc/lib/gcc/current -lgfortran -lquadmath -L/usr/local/Cellar/r/4.2.1_4/lib/R/lib -lR -lintl -Wl,-framework -Wl,CoreFoundation
# installing to /usr/local/Cellar/r/4.2.1_4/lib/R/library/00LOCK-DescTools/00new/DescTools/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** demo
# ** inst
# ** byte-compile and prepare package for lazy loading
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (DescTools)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: Скачанные исходники пакетов находятся в
# 	‘/private/var/folders/_l/lvwb30511nx39kk2yr5zsbxm0000gn/T/Rtmpl7LPot/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Обновляю HTML-список пакетов в '.Library'
#
# R[write to console]: Making 'packages.html' ...
# Во время загрузки - Предупреждения:
# 1: Setting LC_TIME failed, using "C"
# 2: Setting LC_MESSAGES failed, using "C"
# 3: Setting LC_MONETARY failed, using "C"
# R[write to console]:  готово

# %%
# %%R
# tail(names(sort(table(clean_hike_trails$rating))), 1)
# Out:
# [1] "0"
